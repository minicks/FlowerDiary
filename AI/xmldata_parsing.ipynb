# %%
import requests
import pprint

# %%
encoding = 'V7XdQZ5GkRTC16Cr15M8%2FGz%2BEh7hJyAgP6c87dBJtnkNfjaBAKPgW5d7ugY8Cg8usGQiP1lM0K7HUQLRSF8I2A%3D%3D'
decoding = 'V7XdQZ5GkRTC16Cr15M8/Gz+Eh7hJyAgP6c87dBJtnkNfjaBAKPgW5d7ugY8Cg8usGQiP1lM0K7HUQLRSF8I2A=='

# %%
url = 'http://apis.data.go.kr/1390804/NihhsTodayFlowerInfo01'
params ={'serviceKey' : encoding , 'pageNo' : '1', 'numOfRows' : '10', 'searchType' : '4', 'searchWord' : '사랑' }
response = requests.get(url, params=params)

# xml 내용
content = response.text

pp = pprint.PrettyPrinter(indent=4)

# %%
from os import name
import xml.etree.ElementTree as et
import pandas as pd
import bs4
from lxml import html
from urllib.parse import urlencode, quote_plus, unquote

# %%
xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)

# %%
row_list = [] # 행값
name_list = [] # 열이름값
value_list = [] #데이터값

# xml 안의 데이터 수집
for i in range(0, len(rows)):
    columns = rows[i].find_all()
    #첫째 행 데이터 수집
    for j in range(0,len(columns)):
        if i ==0:
            # 컬럼 이름 값 저장
            name_list.append(columns[j].name)
        # 컬럼의 각 데이터 값 저장
        value_list.append(columns[j].text)
    # 각 행의 value값 전체 저장
    row_list.append(value_list)
    # 데이터 리스트 값 초기화
    value_list=[]

# %%
flower_df = pd.DataFrame(row_list, columns=name_list)
print(flower_df.head(19))
